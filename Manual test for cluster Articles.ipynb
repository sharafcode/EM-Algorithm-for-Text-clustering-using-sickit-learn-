# %%
import sframe as sf
import pandas as pd

# %%
cluster_9 = pd.read_csv('Clusters_model20/cluster_9.csv')
cluster_9
# Out:
#       X1                              file_name     category  \
# 0     50  training-dataset/engineering/1404.txt  engineering
# 1    136   training-dataset/engineering/220.txt  engineering
# 2    383  training-dataset/engineering/1106.txt  engineering
# 3    463  training-dataset/engineering/1499.txt  engineering
# 4    720  training-dataset/engineering/1481.txt  engineering
# 5    805  training-dataset/engineering/1221.txt  engineering
# 6    933   training-dataset/engineering/748.txt  engineering
# 7    954   training-dataset/engineering/680.txt  engineering
# 8    957   training-dataset/engineering/671.txt  engineering
# 9   1051  training-dataset/engineering/1306.txt  engineering
# 10  1060  training-dataset/engineering/1502.txt  engineering
# 11  1130       training-dataset/product/265.txt      product
# 12  1177   training-dataset/engineering/642.txt  engineering
# 13  1199   training-dataset/engineering/881.txt  engineering
# ...

# %%
cluster_8= pd.read_csv('Clusters_model20/cluster_8.csv')
cluster_8
# Out:
#       X1                           file_name  category  \
# 0     30   training-dataset/business/406.txt  business
# 1     53  training-dataset/business/1008.txt  business
# 2    122  training-dataset/business/1186.txt  business
# 3    133  training-dataset/business/1096.txt  business
# 4    147  training-dataset/business/1234.txt  business
# 5    265   training-dataset/business/702.txt  business
# 6    268   training-dataset/business/604.txt  business
# 7    292   training-dataset/business/862.txt  business
# 8    377   training-dataset/business/492.txt  business
# 9    474  training-dataset/business/1177.txt  business
# 10   486   training-dataset/business/312.txt  business
# 11   491  training-dataset/business/1244.txt  business
# 12   496   training-dataset/business/416.txt  business
# 13   534  training-dataset/business/1192.txt  business
# 14   546   training-dataset/business/154.txt  business
# 15   569  training-dataset/business/1124.txt  business
# ...
